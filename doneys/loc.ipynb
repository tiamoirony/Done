# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import platform
from datetime import datetime,timedelta

import folium
import json

from folium import plugins


# 운영체제별 한글 폰트 설정
if platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
df_1 = pd.read_csv('data/camp_location.csv')
df_2 = pd.read_csv('data/camp_location_1.csv')
df_3 = pd.read_csv('data/common_location.csv')

# %%
df_1.isnull().sum()
# Out:
# Unnamed: 0     0
# 관광지명           0
# lat           12
# lon           12
# dtype: int64

# %%
df_1=df_1.dropna(subset=['lat'])
df_1=df_1.dropna(subset=['lon'])

# %%
df_2.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739
# 2           2                  경남 함안군  35.272559  128.406480
# 3           3                  서울 강동구  37.530125  127.123762
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493

# %%
df_2.isnull().sum()
# Out:
# Unnamed: 0    0
# 관광지명          0
# lat           1
# lon           1
# dtype: int64

# %%
df_2=df_2.dropna(subset=['lat'])
df_2=df_2.dropna(subset=['lon'])

# %%
df_3=df_3.dropna(subset=['lat'])
df_3=df_3.dropna(subset=['lon'])

# %%
df_3.head()
# Out:
#    Unnamed: 0                  소재지전체주소        lat         lon
# 0           0         경기도 의정부시 호원동 163  37.695106  127.046636
# 1           1    경기도 포천시 화현면 명덕리 179-1  37.872362  127.278410
# 2           2   경상남도 밀양시 산내면 삼양리 산 138  35.598416  128.951944
# 3           3  충청남도 보령시 웅천읍 관당리 645-14  36.259644  126.541331
# 4           4     경기도 가평군 북면 화악리 741-7  37.932761  127.547068

# %%
df_3.rename(columns={'소재지전체주소':'관광지명'}, inplace=True)

# %%
df_3.head()
# Out:
#    Unnamed: 0                     관광지명        lat         lon
# 0           0         경기도 의정부시 호원동 163  37.695106  127.046636
# 1           1    경기도 포천시 화현면 명덕리 179-1  37.872362  127.278410
# 2           2   경상남도 밀양시 산내면 삼양리 산 138  35.598416  128.951944
# 3           3  충청남도 보령시 웅천읍 관당리 645-14  36.259644  126.541331
# 4           4     경기도 가평군 북면 화악리 741-7  37.932761  127.547068

# %%
df_4 = pd.concat([df_2,df_3])

# %%
df_4.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739
# 2           2                  경남 함안군  35.272559  128.406480
# 3           3                  서울 강동구  37.530125  127.123762
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493

# %%
df_4['특별/도'] = df_4['관광지명'].apply(lambda x : x.split(' ')[0])
df_4['시/군'] = df_4['관광지명'].apply(lambda x : x.split(' ')[1])

# %%
df_4.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon 특별/도  시/군
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378   경기  포천시
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739   경북  칠곡군
# 2           2                  경남 함안군  35.272559  128.406480   경남  함안군
# 3           3                  서울 강동구  37.530125  127.123762   서울  강동구
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493   강원  평창군

# %%
df_4
# Out:
#       Unnamed: 0                         관광지명        lat         lon  특별/도  \
# 0              0       경기 포천시 포천로2811번길 178-0  37.993553  127.157378    경기
# 1              1           경북 칠곡군 학하4길 57-105  36.095306  128.485739    경북
# 2              2                       경남 함안군  35.272559  128.406480    경남
# 3              3                       서울 강동구  37.530125  127.123762    서울
# 4              4          강원 평창군 이승복생가길 160-0  37.712629  128.480493    강원
# ...          ...                          ...        ...         ...   ...
# 3414        3414     충청남도 태안군 원북면 방갈리 515-8번지  36.898351  126.207960  충청남도
# 3415        3415   충청남도 태안군 소원면 파도리 543-636번지  36.743035  126.148855  충청남도
# 3416        3416  충청남도 태안군 근흥면 도황리 1526-184번지  36.695214  126.211471  충청남도
# 3417        3417  충청남도 태안군 안면읍 승언리 산 18-566번지  36.514430  126.352918  충청남도
# 3418        3418    충청남도 태안군 남면 신장리 353-148번지  36.673139  126.288661  충청남도
#
#       시/군
# 0     포천시
# 1     칠곡군
# 2     함안군
# 3     강동구
# 4     평창군
# ...   ...
# 3414  태안군
# 3415  태안군
# 3416  태안군
# 3417  태안군
# 3418  태안군
#
# [3543 rows x 6 columns]

# %%
latitude, longitude = 35.9078, 127.7669 # 대한민국의 좌표
S_korea = folium.Map(location = [latitude, longitude], zoom_start = 8)

# %%
S_korea.add_child(plugins.HeatMap(zip(df_4['lat'],
                                      df_4['lon'],
                                      ), radius=18))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8386f75c9c7c4814d8ad19164be46081 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8386f75c9c7c4814d8ad19164be46081&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8386f75c9c7c4814d8ad19164be46081 = L.map(
#                 &quot;map_8386f75c9c7c4814d8ad19164be46081&quot;,
#                 {
#                     center: [35.9078, 127.7669],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_998352ceb37fd5d91f17aacf3d033d76 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8386f75c9c7c4814d8ad19164be46081);
#
#
#             var heat_map_b4766e60d8a42e7e9918876703589eaf = L.heatLayer(
#                 [[37.9935529, 127.1573778], [36.0953065, 128.4857395], [35.2725591, 128.4064797], [37.5301251, 127.123762], [37.7126287, 128.4804926], [36.5675773, 129.4230584], [35.6413164, 126.4800746], [36.5896, 126.2902032], [37.2753925, 127.0674623], [37.1175186, 127.3118503], [37.2915728, 127.6645132], [37.7433164, 126.5571836], [37.7034746, 126.6548693], [35.2285451, 128.8893517], [38.0167127, 126.9752383], [37.567888, 126.878155], [37.1039535, 128.6804881], [36.3545224, 127.3836025], [37.5711136, 126.6704459], [37.5677554, 126.8856819], [35.3547968, 127.5581568], [37.1325821, 128.1909481], [37.2767504, 126.5587395], [37.2012551, 126.5602325], [37.20147, 126.6448632], [35.2122157, 128.9805666], [36.4505206, 127.4687764], [38.0673925, 127.2395456], [37.6529829, 127.3701474], [36.8641665, 128.0878749], [37.4559536, 126.8598487], [38.0499025, 127.3823053], [37.2521998, 128.6149414], [37.593441, 126.4586944], [37.8920642, 126.8404835], [37.53695039999999, 126.7377435], [36.930542, 126.2953281], [37.5311952, 129.1068506], [37.5311952, 129.1068506], [36.9910113, 127.9259497], [36.6744285, 126.285953], [36.6696446, 126.2871932], [36.7456421, 126.2980528], [36.6736817, 126.2822644], [37.7404912, 126.5353096], [37.3819253, 126.8286301], [35.5037598, 128.7464415], [38.0895173, 128.6581241], [38.3016239, 128.5458715], [37.9823583, 127.2421576], [37.645479, 126.597029], [37.5936717, 128.0574155], [37.7041641, 127.6056728], [38.3801292, 128.4674385], [38.0753925, 128.6188503], [37.2105949, 126.8946112], [35.1526399, 128.9908173], [36.7775109, 126.3513988], [37.8469633, 127.3466885], [37.429246, 126.9874451], [36.7456421, 126.2980528], [38.1626092, 128.5443188], [37.2514543, 127.7555895], [37.751853, 128.8760574], [37.1366803, 127.2139721], [37.5406722, 127.4692239], [38.09151550000001, 128.6537962], [37.328109, 128.2710353], [38.3440485, 128.511709], [37.5711136, 126.6704459], [35.1221068, 126.9079579], [37.213889, 126.178333], [37.634535, 126.3751961], [36.7918275, 126.9929535], [38.07331, 127.0070259], [38.089695, 128.6561398], [37.4912195, 127.4875607], [37.4912195, 127.4875607], [36.7531808, 126.1405712], [36.7531808, 126.1405712], [37.8580844, 128.8530771], [37.4737341, 126.6214796], [37.619122, 126.381686], [36.0724234, 129.0672676], [36.11185830000001, 128.2443001], [36.3207099, 127.6253808], [35.952486, 127.5281078], [37.124696, 127.3114748], [35.3350072, 129.0371689], [37.9748265, 127.1509471], [37.3735142, 127.5893231], [37.4469893, 126.7319416], [37.4094099, 126.6783088], [37.6723732, 127.1586185], [37.8925252, 126.7445393], [37.8209476, 127.5208644], [37.2853447, 129.3124387], [38.0692505, 127.1082386], [37.6066977, 127.1101168], [36.9921075, 127.1129451], [36.7850674, 127.4212526], [37.5454212, 126.6759723], [37.4783662, 129.1581726], [36.1666693, 126.5258903], [37.0274527, 128.0416064], [35.9953059, 128.4015434], [36.1358159, 129.3848664], [37.2850251, 127.2169014], [37.8939253, 127.3061238], [37.71805459999999, 127.4516942], [35.5224173, 129.0176708], [37.67475719999999, 126.7557402], [37.370474, 128.3899769], [38.0167127, 126.9752383], [37.9412549, 127.1356197], [37.2599457, 128.1638014], [36.89769769999999, 126.2076783], [38.0147057, 127.068102], [37.6120401, 126.4530611], [37.9612452, 128.525577], [37.2674188, 126.5605635], [35.1259867, 128.9634308], [36.683324, 127.8063472], [35.4850366, 127.9977164], [35.3059959, 128.9834505], [37.7845677, 127.0997292], [37.6518188, 128.3137355], [37.6951064, 127.046636], [37.8723616, 127.2784102], [35.5984157, 128.9519444], [36.2596442, 126.5413313], [37.9327613, 127.5470684], [38.1889599, 128.3620907], [37.8439094, 127.1067708], [35.2108405, 127.7648066], [35.24523, 127.8862099], [38.0081618, 126.9479419], [34.6330186, 127.0303153], [36.9163648, 128.8283573], [37.4274391, 127.6062587], [36.3626317, 127.3186977], [37.4748563, 130.8318988], [37.8637445, 127.1187874], [37.49557009999999, 127.5310051], [35.9198111, 128.6509025], [35.4319307, 127.0588251], [37.5642189, 12

# %%
df_4.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon 특별/도  시/군
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378   경기  포천시
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739   경북  칠곡군
# 2           2                  경남 함안군  35.272559  128.406480   경남  함안군
# 3           3                  서울 강동구  37.530125  127.123762   서울  강동구
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493   강원  평창군

# %%
address1 = df_4.groupby('특별/도',as_index=False).agg(개수=('관광지명','count'))

# %%
geo_path = 'data/map.geojson'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
df_map = folium.Map(location=[36, 127], zoom_start=7)
choropleth = folium.Choropleth(geo_data=geo_str,
                               data = address1,
                               columns=('특별/도', '개수'),
                               key_on='feature.properties.CTP_KOR_NM',
                               fill_color='PuRd').add_to(df_map)
plugins.MousePosition().add_to(df_map)
df_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8174e4961dda387d7b015aa8f90d6444 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8174e4961dda387d7b015aa8f90d6444&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8174e4961dda387d7b015aa8f90d6444 = L.map(
#                 &quot;map_8174e4961dda387d7b015aa8f90d6444&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b16c9e43a925d570b679c3768b1605b2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8174e4961dda387d7b015aa8f90d6444);
#
#
#             var choropleth_5c00de1da5358303a550ccf662d4983d = L.featureGroup(
#                 {}
#             ).addTo(map_8174e4961dda387d7b015aa8f90d6444);
#
#
#         function geo_json_1e821d29731eb3b407fecd59653e50a6_styler(feature) {
#             switch(feature.properties.CTPRVN_CD) {
#                 case 27: case 36: case 31: case 46: case 50:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1e821d29731eb3b407fecd59653e50a6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e821d29731eb3b407fecd59653e50a6 = L.geoJson(null, {
#                 onEachFeature: geo_json_1e821d29731eb3b407fecd59653e50a6_onEachFeature,
#
#                 style: geo_json_1e821d29731eb3b407fecd59653e50a6_styler,
#         });
#
#         function geo_json_1e821d29731eb3b407fecd59653e50a6_add (data) {
#             geo_json_1e821d29731eb3b407fecd59653e50a6
#                 .addData(data)
#                 .addTo(choropleth_5c00de1da5358303a550ccf662d4983d);
#         }
#             geo_json_1e821d29731eb3b407fecd59653e50a6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[128.54880989370014, 38.301950820518755], [128.5600921732829, 38.25735515107489], [128.59761716763322, 38.21480959198724], [128.60765942875406, 38.15215810015938], [128.64206854447866, 38.106588627599855], [128.66939445927846, 38.08634208760778], [128.69458333244307, 38.0453480455091], [128.73326744935343, 38.01787054352603], [128.79463671088126, 37.92801060958252], [128.8233689458956, 37.90753318801803], [128.83001997197184, 37.88458455426084], [128.8786226699225, 37.8294251483049], [128.9852771172376, 37.74045442473868], [129.01482411622038, 37.70600771921262], [129.05505018456222, 37.675224044111836], [129.04353313092116, 37.642745963305245], [129.05392180246835, 37.62123228307141], [129.11550878570839, 37.57855036235084], [129.12163400699842, 37.52066201439543], [129.18932196241568, 37.45204451034289], [129.19776432627512, 37.41521414735909], [129.2513233979134, 37.380088360708676], [129.2506772120506, 37.362368874276115], [129.28084694703435, 37.31347366301054], [129.35527819358379, 37.235059804121235], [129.3411918281742, 37.17718338225454], [129.3633972863588, 37.146000904866405], [129.32482985566594, 37.142286218870495], [129.271238269404, 37.1163805689057], [129.22537770639696, 37.073720111851664], [129.2253141304669, 37.04455999175614], [129.18540948720124, 37.04171908095918], [129.1850295662585, 37.04657953042605], [129.18167891525556, 37.050424880670846], [129.181333033076, 37.05162367047038], [129.1804325873684, 37.05243956004464], [129.18042225596662, 37.05322104542962], [129.17705384944216, 37.05671598015327], [129.1757059210262, 37.05780315753493], [129.17039771110316, 37.06035604623057], [129.169731709345, 37.06153035273092], [129.16965828604876, 37.062130475530964], [129.1693452740602, 37.06274071555654], [129.1692154824529, 37.06343855741099], [129.1667786382645, 37.065216264525716], [129.16663358375598, 37.065846086142365], [129.16626037723566, 37.06671727729185], [129.16583175157555, 37.06737637989426], [129.16618416883838, 37.06921625222834], [129.16169241045623, 37.068883557546876], [129.15477987484462, 37.07180739051456], [129.152593437702, 37.073430543687365], [129.15211560438644, 37.073230583464394], [129.1511766786477, 37.07415934489281], [129.1497563868977, 37.07448385475696], [129.148045601

# %%
df_4.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon 특별/도  시/군
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378   경기  포천시
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739   경북  칠곡군
# 2           2                  경남 함안군  35.272559  128.406480   경남  함안군
# 3           3                  서울 강동구  37.530125  127.123762   서울  강동구
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493   강원  평창군

# %%
import numpy as np

# %%
df_4['출발지경도'] = np.NaN
df_4['출발지위도'] = np.NaN

# %%
df_4['출발지경도'] = df_4['출발지경도'].fillna(37.526989, axis=0)
df_4['출발지위도'] = df_4['출발지위도'].fillna(126.932098, axis=0)

# %%
df_4.head()
# Out:
#    Unnamed: 0                    관광지명        lat         lon 특별/도  시/군  \
# 0           0  경기 포천시 포천로2811번길 178-0  37.993553  127.157378   경기  포천시
# 1           1      경북 칠곡군 학하4길 57-105  36.095306  128.485739   경북  칠곡군
# 2           2                  경남 함안군  35.272559  128.406480   경남  함안군
# 3           3                  서울 강동구  37.530125  127.123762   서울  강동구
# 4           4     강원 평창군 이승복생가길 160-0  37.712629  128.480493   강원  평창군
#
#        출발지경도       출발지위도
# 0  37.526989  126.932098
# 1  37.526989  126.932098
# 2  37.526989  126.932098
# 3  37.526989  126.932098
# 4  37.526989  126.932098

# %%
import pydeck as pdk

from mapboxgl.viz import *
from mapboxgl.utils import *

MAPBOX_API_KEY = "pk.eyJ1IjoidGlhbW9pcm9ueSIsImEiOiJjbGI1d2hwZWgwMHRuM3lxdmdraXNsdTY3In0.YQJdEgWDZQrQs8yQSDMZ8w"

# get_width='1 + 10 * 정규화_이용',

layer = pdk.Layer(
    'LineLayer',
    df_4,
    get_source_position= '[출발지경도, 출발지위도]',
    get_target_position='[lat, lon]',
    get_source_color='[255, 255, 120]',
    get_target_color='[255, 0, 0]',
    pickable=True,
    auto_highlight=True)


# pydeck.data_utils.compute_view 는 Points 들의 경도, 위도를 리스트로 주면, 알아서 view_state 를 만들어줍니다.

view_state = pdk.data_utils.compute_view(df_4[['출발지경도', '출발지위도']].values)
view_state.zoom = 13

r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.show()
