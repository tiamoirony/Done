# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import Select
import pyautogui
import time
import openpyxl

import requests
import json
import csv

from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')

driver.get('https://m.thankqcamping.com/resv/list.hbb?ser_long_yn=Y')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17032\3765266241.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/usr/local/bin/chromedriver')

# %%
# 현재 마우스 커서의 위치 출력
print(pyautogui.position())
# Out:
# Point(x=835, y=821)

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')

driver.get('https://m.thankqcamping.com/resv/list.hbb?ser_long_yn=Y')

time.sleep(2)

pyautogui.click(336, 353)
time.sleep(1)

pyautogui.click(500, 818)
time.sleep(1)

pyautogui.click(662, 936)
time.sleep(1)

pyautogui.click(597, 348)
time.sleep(1)

pyautogui.click(835, 821)
time.sleep(1)

pyautogui.click(662, 936)
time.sleep(5)



for i in range(50):
    driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END)
    time.sleep(7)


infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")

for info in infos:
    try:
        title = info.find_element(By.CSS_SELECTOR, ".tit").text
        reple = info.find_element(By.CSS_SELECTOR, ".li_E0001").text
        
        
        etc = info.find_element(By.CSS_SELECTOR, ".li_EA000").text
        
        
        
        print('캠핑장이름:', title)
        print('========================================================================================================================================================================================')
        print('조회수:', reple)
        print('========================================================================================================================================================================================')
        print('기타:', etc)
    except:
        pass
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3812\1414901971.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/usr/local/bin/chromedriver')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\USER\Desktop\Done\cra\thank.ipynb 셀 4 in <cell line: 27>()
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/Done/cra/thank.ipynb#W2sZmlsZQ%3D%3D?line=26'>27</a> for i in range(50):
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/Done/cra/thank.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a>     driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/Done/cra/thank.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a>     time.sleep(7)
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/Done/cra/thank.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a> infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/Done/cra/thank.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a> for info in infos:
#
# KeyboardInterrupt:

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')

driver.get('https://m.thankqcamping.com/resv/list.hbb?ser_long_yn=Y')

time.sleep(2)

pyautogui.click(336, 353)
time.sleep(1)

pyautogui.click(500, 818)
time.sleep(1)

pyautogui.click(662, 936)
time.sleep(1)

pyautogui.click(597, 348)
time.sleep(1)

pyautogui.click(835, 821)
time.sleep(1)

pyautogui.click(662, 936)
time.sleep(5)

wb = openpyxl.Workbook()
ws = wb.active

ws.append(['이름', '조회순', '기타'])

for i in range(20):
    driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END)
    time.sleep(5)


infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")

for info in infos:
    try:
        title = info.find_element(By.CSS_SELECTOR, ".tit").text
        reple = info.find_element(By.CSS_SELECTOR, ".li_E0001").text
        
        
        etc = info.find_element(By.CSS_SELECTOR, ".li_EA000").text
        
        print('캠핑장이름:', title)
        print('========================================================================================================================================================================================')
        print('조회수:', reple)
        print('========================================================================================================================================================================================')
        print('기타:', etc)
        
        ws.append([title, reple, etc])
 
    except:
        pass


wb.save(f"thank조회순.xlsx")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3812\1564423413.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/usr/local/bin/chromedriver')
# 캠핑장이름: 황매산오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (403)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (185)
# 캠핑장이름: SE 클럽 (태안둘레길캠핑장)
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (254)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (89)
# 캠핑장이름: 안녕오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (214)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (108)
# 캠핑장이름: 산들바다관광농원 캠핑장&펜션
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (213)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (88)
# 캠핑장이름: 곰섬캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (190)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (86)
# 캠핑장이름: 춘천숲자연휴양림 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (170)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (37)
# 캠핑장이름: 가평 화랑캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (143)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (60)
# 캠핑장이름: 문수산오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (140)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (36)
# 캠핑장이름: 가평 무릉도원캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (139)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (68)
# 캠핑장이름: 포천 유식물원 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (133)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (79)
# 캠핑장이름: 놀터캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (133)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (53)
# 캠핑장이름: 산청지막계곡캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (119)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (31)
# 캠핑장이름: 캠핑808 충주호
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (117)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (102)
# 캠핑장이름: 가평 대가캠핑유원지
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (117)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (43)
# 캠핑장이름: 포천계곡캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (116)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (46)
# 캠핑장이름: 창원휴양림 오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (116)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (25)
# 캠핑장이름: 양주 하늘캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (114)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (49)
# 캠핑장이름: 주전패밀리캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (104)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (34)
# 캠핑장이름: 인제캠핑타운
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (104)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (36)
# 캠핑장이름: 서해땅끝 파도리 아치내 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (102)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (28)
# 캠핑장이름: 밀양 산여울캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (99)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (48)
# 캠핑장이름: 브라보캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (95)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (27)
# 캠핑장이름: 백경오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (94)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (44)
# 캠핑장이름: 강촌 스칼라 캠프
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (91)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (75)
# 캠핑장이름: 느루캠핑
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (88)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (62)
# 캠핑장이름: 캠핑드림
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (82)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (79)
# 캠핑장이름: 해씨유캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (79)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (47)
# 캠핑장이름: 고길동캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (78)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (25)
# 캠핑장이름: 십리포해수욕장캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (75)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (46)
# 캠핑장이름: 숲속에안뜰
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (68)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (27)
# 캠핑장이름: 네스트 캠핑&펜션
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (67)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (46)
# 캠핑장이름: 에이미캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (65)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (35)
# 캠핑장이름: 고포수변공원캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (63)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (13)
# 캠핑장이름: 모짜르트 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (61)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (42)
# 캠핑장이름: 화악산캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (57)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (57)
# 캠핑장이름: 래미안밸리 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (56)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (25)
# 캠핑장이름: 석양마을 주포캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (51)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (28)
# 캠핑장이름: 자연펜션캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (48)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (21)
# 캠핑장이름: 학현 아름마을오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (44)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (24)
# 캠핑장이름: 갈천오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (43)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (15)
# 캠핑장이름: 서석캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (42)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (24)
# 캠핑장이름: 영학관광농원캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (42)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (18)
# 캠핑장이름: 백리포 바다와 파도소리캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (39)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (44)
# 캠핑장이름: 쌍곡예당
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (38)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (17)
# 캠핑장이름: 해맞이 바다풍경캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (36)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (37)
# 캠핑장이름: 지리산365오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (33)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (25)
# 캠핑장이름: 자연쉼터빌리지
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (33)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (4)
# 캠핑장이름: 파인트리캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (32)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (18)
# 캠핑장이름: 부귀농원 가족캠프
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (32)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (16)
# 캠핑장이름: 해담 구룡령 야영장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (32)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (14)

# %%
ws.append(['이름', '조회순', '기타'])

for i in range(10):
    driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END)
    time.sleep(5)


infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")

for info in infos:
    try:
        title = info.find_element(By.CSS_SELECTOR, ".tit").text
        reple = info.find_element(By.CSS_SELECTOR, ".li_E0001").text
        
        
        etc = info.find_element(By.CSS_SELECTOR, ".li_EA000").text
        
        print('캠핑장이름:', title)
        print('========================================================================================================================================================================================')
        print('조회수:', reple)
        print('========================================================================================================================================================================================')
        print('기타:', etc)
        
        ws.append([title, reple, etc])
 
    except:
        pass


wb.save(f"thank조회순.xlsx")

# %%
ws.append(['이름', '조회순', '기타'])

infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")

for info in infos:
    try:
        title = info.find_element(By.CSS_SELECTOR, ".tit").text
        reple = info.find_element(By.CSS_SELECTOR, ".li_E0001").text
        
        
        etc = info.find_element(By.CSS_SELECTOR, ".li_EA000").text
        
        print('캠핑장이름:', title)
        print('========================================================================================================================================================================================')
        print('조회수:', reple)
        print('========================================================================================================================================================================================')
        print('기타:', etc)
        
        ws.append([title, reple, etc])
 
    except:
        pass


wb.save(f"thank조회순2.xlsx")
