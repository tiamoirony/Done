# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.ui import Select
import pyautogui
import time
import openpyxl

import requests
import json
import csv

from bs4 import BeautifulSoup

# %%
# 현재 마우스 커서의 위치 출력
print(pyautogui.position())
# Out:
# Point(x=477, y=869)

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')

driver.get('https://m.thankqcamping.com/resv/list.hbb?ser_long_yn=Y')

time.sleep(2)

pyautogui.click(379, 285)
time.sleep(1)

pyautogui.click(477, 869)
time.sleep(1)

pyautogui.click(642, 954)
time.sleep(1)

pyautogui.click(572, 284)
time.sleep(1)

pyautogui.click(761, 888)
time.sleep(1)

pyautogui.click(642, 954)
time.sleep(5)



for i in range(5):
    driver.find_element(By.CSS_SELECTOR, "body").send_keys(Keys.END)
    time.sleep(2)


infos = driver.find_elements(By.CSS_SELECTOR, ".camp_div")

for info in infos:
    try:
        title = info.find_element(By.CSS_SELECTOR, ".tit").text
        reple = info.find_element(By.CSS_SELECTOR, ".li_E0001").text
        
        
        etc = info.find_element(By.CSS_SELECTOR, ".li_EA000").text
        
        
        
        print('캠핑장이름:', title)
        print('========================================================================================================================================================================================')
        print('조회수:', reple)
        print('========================================================================================================================================================================================')
        print('기타:', etc)
    except:
        pass
# Out:
# C:\Users\tiamo\AppData\Local\Temp\ipykernel_1500\1705980531.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/usr/local/bin/chromedriver')
# 캠핑장이름: 황매산오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (403)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (185)
# 캠핑장이름: SE 클럽 (태안둘레길캠핑장)
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (254)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (89)
# 캠핑장이름: 안녕오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (214)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (108)
# 캠핑장이름: 산들바다관광농원 캠핑장&펜션
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (213)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (88)
# 캠핑장이름: 곰섬캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (190)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (86)
# 캠핑장이름: 춘천숲자연휴양림 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (170)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (37)
# 캠핑장이름: 가평 화랑캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (143)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (60)
# 캠핑장이름: 문수산오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (140)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (36)
# 캠핑장이름: 가평 무릉도원캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (139)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (68)
# 캠핑장이름: 포천 유식물원 캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (133)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (79)
# 캠핑장이름: 놀터캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (133)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (53)
# 캠핑장이름: 산청지막계곡캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (119)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (31)
# 캠핑장이름: 캠핑808 충주호
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (117)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (102)
# 캠핑장이름: 가평 대가캠핑유원지
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (117)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (43)
# 캠핑장이름: 포천계곡캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (116)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (46)
# 캠핑장이름: 창원휴양림 오토캠핑장
# ========================================================================================================================================================================================
# 조회수: 캠핑후기 (116)
# ========================================================================================================================================================================================
# 기타: 뷰가 좋아요 (25)
