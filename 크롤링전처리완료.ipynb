# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import platform
from datetime import datetime,timedelta


# 운영체제별 한글 폰트 설정
if platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
data1 = pd.read_excel('cra/조회순.xlsx')
data2 = pd.read_excel('cra/thank조회순.xlsx')

# %%
data1
# Out:
#              조회수                           제목                          주소  \
# 0     조회수 227159       [경상남도 사천시] 사천비토솔섬오토캠핑장     경남 사천시 서포면 토끼로 245-29
# 1     조회수 140635       [강원도 정선군] 동강전망휴양림오토캠핑장     강원 정선군 신동읍 동강로 916-212
# 2     조회수 112938           [충청북도 충주시] 충주카누캠핑장      충북 충주시 동량면 지등로 1276-4
# 3      조회수 98685   [전라북도 정읍시] 정읍시 내장산 국민여가캠핑장         전라북도 정읍시 내장산로 390
# 4      조회수 92517  [전라북도 부안군] 변산반도국립공원 고사포 야영장   전라북도 부안군 변산면 운산리 441-11
# ...          ...                          ...                         ...
# 1455    조회수 1826          [인천시 강화군] 우니메이카 강화점  인천 강화군 하점면 창후로228번길 26-16
# 1456    조회수 1458               [강원도 원주시] 우주캠프       강원 원주시 신림면 신림황둔로 676
# 1457    조회수 1400            [경기도 가평군] 아워 포레스트     경기 가평군 가평읍 가화로 440-117
# 1458     조회수 836   [강원도 태백시] 태백산국립공원사무소 소도야영장      강원 태백시 천제단길 181 (소도동)
# 1459     조회수 323                [전라남도 화순군] 소휴         전남 화순군 화순읍 백천로 632
#
#                                           아이콘
# 0     \n전기\n와이파이\n장작판매\n온수\n물놀이장\n놀이터\n운동시설\n
# ...

# %%
data1.isnull().sum()
# Out:
# 조회수    0
# 제목     0
# 주소     0
# 아이콘    0
# dtype: int64

# %%
data1['조회수'] = data1['조회수'].str.replace('조회수 ','')
data1['제목'] = data1['제목'].apply(lambda x : x.split('] ')[1])

# %%
result = '\n'.join(s for s in data1['아이콘'])
result = result.replace('\n',',')
l = result.split(sep=',')
s = set(l)-set([''])

# %%
for i in s:
    data1_s1 = data1[data1['아이콘'].str.contains(i)]
    data1_s2 = data1[~data1['아이콘'].str.contains(i)]
    data1_s1[i] = 1
    data1_s2[i] = 0
    data1 = pd.concat([data1_s1,data1_s2])
# Out:
# C:\Users\BECK\AppData\Local\Temp\ipykernel_27372\358037701.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_s1[i] = 1
# C:\Users\BECK\AppData\Local\Temp\ipykernel_27372\358037701.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1_s2[i] = 0
# C:\Users\BECK\AppData\Local\Temp\ipykernel_27372\358037701.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data1 = data1.drop('아이콘',axis=1)

# %%
#data1.to_csv('크롤링전처리완료.csv',encoding='UTF-8')

# %%
data1
# Out:
#         조회수             제목                             주소  운동시설  산책로  운동장  \
# 33    36970       알멕스랜드캠핑장  경기도 연천군 왕징면 왕산로 218번길 25-100      1    1    1
# 129   22224   함평나비마을 서울캠핑장          전라남도 함평군 함평읍 함장로 730      1    1    1
# 189   19657        고성잔디캠핑장            경남 고성군 하일면 용태리 479      1    1    1
# 202   19099  청도 그린나래 오토캠핑장          경북 청도군 매전면 송원길 122-3      1    1    1
# 302   17172      드림랜드오토캠핑장             경북 영천시 고경면 고도길 38      1    1    1
# ...     ...            ...                            ...   ...  ...  ...
# 583   14491     월성 산아래 글램핑        전라남도 장성군 북하면 월성안길16-33      1    0    0
# 793   13093    신불산폭포 자연휴양림       울산광역시 울주군 상북면 청수골길 175       1    0    0
# 872   12653         (주)자연인       제주특별자치도 제주시 아란서길 110-0       1    0    0
# 894   12582     살구나무글램핑&펜션            강원도 횡성군 경강로 615-19      1    0    0
# 1416   3225          산내956            경북 경주시 산내면 문복로 956      1    0    0
#
#       와이파이  물놀이장  놀이터  마트.편의점  장작판매  전기  트렘폴린  온수
# ...
